# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
DF1=pd.read_csv("movie_data.csv")

# %%
DF1
# Out:
#     Unnamed: 0                                      Name of movie  \
# 0            0                                    The Dark Knight
# 1            1      The Lord of the Rings: The Return of the King
# 2            2                Spider-Man: Across the Spider-Verse
# 3            3                                          Inception
# 4            4  The Lord of the Rings: The Fellowship of the Ring
# 5            5              The Lord of the Rings: The Two Towers
# 6            6                                         The Matrix
# 7            7     Star Wars: Episode V - The Empire Strikes Back
# 8            8                                    Soorarai Pottru
# 9            9                         Terminator 2: Judgment Day
# 10          10                                          Star Wars
# 11          11                               Shichinin no samurai
# 12          12                                            Seppuku
# ...

# %%
DF1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         50 non-null     int64
#  1   Name of movie      50 non-null     object
#  2   Director of movie  50 non-null     object
#  3   Duration of movie  50 non-null     int64
#  4   Year of Release    50 non-null     int64
#  5   Rating             50 non-null     object
#  6   Metascore          50 non-null     object
#  7   vote               50 non-null     object
#  8   gross              50 non-null     object
#  9   Genre              50 non-null     object
#  10  star               50 non-null     object
#  11  Certificate        50 non-null     object
# dtypes: int64(3), object(9)
# memory usage: 4.8+ KB

# %%
DF1.head()
# Out:
#    Unnamed: 0                                      Name of movie  \
# 0           0                                    The Dark Knight
# 1           1      The Lord of the Rings: The Return of the King
# 2           2                Spider-Man: Across the Spider-Verse
# 3           3                                          Inception
# 4           4  The Lord of the Rings: The Fellowship of the Ring
#
#       Director of movie  Duration of movie  Year of Release  \
# 0     Christopher Nolan                152             2008
# 1         Peter Jackson                201             2003
# 2  Joaquim Dos Santos,                 140             2023
# 3     Christopher Nolan                148             2010
# 4         Peter Jackson                178             2001
#
#                            Rating   Metascore       vote     gross  \
# 0    Rate this  123456789109/10X   84          2,758,917  $534.86M
# 1    Rate this  123456789109/10X   94          1,906,233  $377.85M
# ...

# %%
DF1.shape
# Out:
# (50, 12)

# %%
DF1.tail()
# Out:
#     Unnamed: 0                       Name of movie Director of movie  \
# 45          45  Kimetsu no Yaiba: Mugen Ressha-Hen    Haruo Sotozaki
# 46          46                  Gangs of Wasseypur    Anurag Kashyap
# 47          47                             Yôjinbô    Akira Kurosawa
# 48          48                    K.G.F: Chapter 1    Prashanth Neel
# 49          49         Baahubali 2: The Conclusion    S.S. Rajamouli
#
#     Duration of movie  Year of Release                          Rating  \
# 45                117             2020  Rate this  123456789108.2/10X
# 46                321             2012  Rate this  123456789108.2/10X
# 47                110             1961  Rate this  123456789108.2/10X
# 48                156             2018  Rate this  123456789108.2/10X
# 49                167             2017  Rate this  123456789108.2/10X
#
#      Metascore     vote    gross                                      Genre  \
# ...

# %%
DF1.columns
# Out:
# Index(['Unnamed: 0', 'Name of movie', 'Director of movie', 'Duration of movie',
#        'Year of Release', 'Rating', 'Metascore', 'vote', 'gross', 'Genre',
#        'star', 'Certificate'],
#       dtype='object')

# %%
DF1.drop(['Unnamed: 0'],axis=1)
# Out:
#                                         Name of movie     Director of movie  \
# 0                                     The Dark Knight     Christopher Nolan
# 1       The Lord of the Rings: The Return of the King         Peter Jackson
# 2                 Spider-Man: Across the Spider-Verse  Joaquim Dos Santos,
# 3                                           Inception     Christopher Nolan
# 4   The Lord of the Rings: The Fellowship of the Ring         Peter Jackson
# 5               The Lord of the Rings: The Two Towers         Peter Jackson
# 6                                          The Matrix      Lana Wachowski,
# 7      Star Wars: Episode V - The Empire Strikes Back        Irvin Kershner
# 8                                     Soorarai Pottru         Sudha Kongara
# 9                          Terminator 2: Judgment Day         James Cameron
# 10                                          Star Wars          George Lucas
# ...

# %%
DF1
# Out:
#     Unnamed: 0                                      Name of movie  \
# 0            0                                    The Dark Knight
# 1            1      The Lord of the Rings: The Return of the King
# 2            2                Spider-Man: Across the Spider-Verse
# 3            3                                          Inception
# 4            4  The Lord of the Rings: The Fellowship of the Ring
# 5            5              The Lord of the Rings: The Two Towers
# 6            6                                         The Matrix
# 7            7     Star Wars: Episode V - The Empire Strikes Back
# 8            8                                    Soorarai Pottru
# 9            9                         Terminator 2: Judgment Day
# 10          10                                          Star Wars
# 11          11                               Shichinin no samurai
# 12          12                                            Seppuku
# ...

# %%
#finding missing value 
DF1.isnull().sum()
# Out:
# Unnamed: 0           0
# Name of movie        0
# Director of movie    0
# Duration of movie    0
# Year of Release      0
# Rating               0
# Metascore            0
# vote                 0
# gross                0
# Genre                0
# star                 0
# Certificate          0
# dtype: int64

# %%
DF1.isnull()
# Out:
#     Unnamed: 0  Name of movie  Director of movie  Duration of movie  \
# 0        False          False              False              False
# 1        False          False              False              False
# 2        False          False              False              False
# 3        False          False              False              False
# 4        False          False              False              False
# 5        False          False              False              False
# 6        False          False              False              False
# 7        False          False              False              False
# 8        False          False              False              False
# 9        False          False              False              False
# 10       False          False              False              False
# 11       False          False              False              False
# 12       False          False              False              False
# ...

# %%
sns.heatmap(DF1.isnull())
# Out:
# <AxesSubplot:>

# %%
per_missing=DF1.isnull().sum()*100/len(DF1)

# %%
per_missing
# Out:
# Unnamed: 0           0.0
# Name of movie        0.0
# Director of movie    0.0
# Duration of movie    0.0
# Year of Release      0.0
# Rating               0.0
# Metascore            0.0
# vote                 0.0
# gross                0.0
# Genre                0.0
# star                 0.0
# Certificate          0.0
# dtype: float64

# %%
# Duplicate values
dup_df=DF1.duplicated().any()

# %%
print("Are there any duplicate values?",dup_df)
# Out:
# Are there any duplicate values? False

# %%
DF1.drop_duplicates()
# Out:
#     Unnamed: 0                                      Name of movie  \
# 0            0                                    The Dark Knight
# 1            1      The Lord of the Rings: The Return of the King
# 2            2                Spider-Man: Across the Spider-Verse
# 3            3                                          Inception
# 4            4  The Lord of the Rings: The Fellowship of the Ring
# 5            5              The Lord of the Rings: The Two Towers
# 6            6                                         The Matrix
# 7            7     Star Wars: Episode V - The Empire Strikes Back
# 8            8                                    Soorarai Pottru
# 9            9                         Terminator 2: Judgment Day
# 10          10                                          Star Wars
# 11          11                               Shichinin no samurai
# 12          12                                            Seppuku
# ...

# %%
DF1.shape
# Out:
# (50, 12)

# %%
DF1.describe(include='all')
# Out:
#         Unnamed: 0    Name of movie  Director of movie  Duration of movie  \
# count     50.00000               50                 50          50.000000
# unique         NaN               50                 37                NaN
# top            NaN  The Dark Knight  Christopher Nolan                NaN
# freq           NaN                1                  4                NaN
# mean      24.50000              NaN                NaN         148.280000
# std       14.57738              NaN                NaN          34.273831
# min        0.00000              NaN                NaN         101.000000
# 25%       12.25000              NaN                NaN         130.250000
# 50%       24.50000              NaN                NaN         140.500000
# 75%       36.75000              NaN                NaN         162.750000
# max       49.00000              NaN                NaN         321.000000
#
#         Year of Release                          Rating Metascore       vote  \
# ...

# %%
DF1.columns
# Out:
# Index(['Unnamed: 0', 'Name of movie', 'Director of movie', 'Duration of movie',
#        'Year of Release', 'Rating', 'Metascore', 'vote', 'gross', 'Genre',
#        'star', 'Certificate'],
#       dtype='object')

# %%
DF1[DF1['Duration of movie']>=180]['Name of movie']
# Out:
# 1     The Lord of the Rings: The Return of the King
# 11                             Shichinin no samurai
# 17                                Avengers: Endgame
# 46                               Gangs of Wasseypur
# Name: Name of movie, dtype: object

# %% [markdown]
# # first prediction Highest voting

# %%
# In which year there was highest average voting

# %%
DF1['Year of Release'].value_counts().sort_values()
# Out:
# 1961    1
# 2010    1
# 2001    1
# 2002    1
# 1999    1
# 1980    1
# 1991    1
# 1977    1
# 1954    1
# 1962    1
# 2000    1
# 1994    1
# 1981    1
# 2008    1
# 1995    1
# 1959    1
# 2017    1
# 1983    1
# 1997    1
# 2016    1
# 1986    1
# 1993    1
# 1989    1
# 1988    1
# 1985    1
# 2023    1
# 2005    2
# 2021    2
# 2012    2
# 2020    2
# 2003    3
# 2018    4
# 2019    4
# 2022    5
# Name: Year of Release, dtype: int64

# %%
DF1['vote']
# Out:
# 0     2,758,917
# 1     1,906,233
# 2       206,468
# 3     2,449,278
# 4     1,934,425
# 5     1,720,128
# 6     1,978,806
# 7     1,334,656
# 8       120,272
# 9     1,135,330
# 10    1,406,687
# 11      356,113
# 12       62,768
# 13       61,883
# 14    1,552,425
# 15    1,202,153
# 16    1,764,288
# 17    1,203,203
# 18      617,723
# 19    1,007,793
# 20      739,374
# 21      604,443
# 22    1,144,915
# 23       37,004
# 24       31,663
# 25      619,462
# 26      686,781
# 27      337,300
# 28    1,087,899
# 29      412,469
# 30      200,047
# 31       97,285
# 32       65,180
# 33      141,531
# 34      125,850
# 35       47,664
# 36    1,523,851
# 37      821,069
# 38    1,027,365
# 39      634,919
# 40      787,448
# 41    1,152,007
# 42    1,149,225
# 43      908,728
# 44      130,917
# 45       66,771
# 46      100,142
# 47      127,188
# 48       92,933
# 49      108,472
# Name: vote, dtype: object

# %%
DF1['vote']=DF1['vote'].str.replace(',','')

# %%
DF1['vote']=DF1['vote'].astype(int)

# %%
DF1['vote']
# Out:
# 0     2758917
# 1     1906233
# 2      206468
# 3     2449278
# 4     1934425
# 5     1720128
# 6     1978806
# 7     1334656
# 8      120272
# 9     1135330
# 10    1406687
# 11     356113
# 12      62768
# 13      61883
# 14    1552425
# 15    1202153
# 16    1764288
# 17    1203203
# 18     617723
# 19    1007793
# 20     739374
# 21     604443
# 22    1144915
# 23      37004
# 24      31663
# 25     619462
# 26     686781
# 27     337300
# 28    1087899
# 29     412469
# 30     200047
# 31      97285
# 32      65180
# 33     141531
# 34     125850
# 35      47664
# 36    1523851
# 37     821069
# 38    1027365
# 39     634919
# 40     787448
# 41    1152007
# 42    1149225
# 43     908728
# 44     130917
# 45      66771
# 46     100142
# 47     127188
# 48      92933
# 49     108472
# Name: vote, dtype: int32

# %%
DF1['vote'].min(axis=0)
# Out:
# 31663

# %%
DF1['vote'].max(axis=0)
# Out:
# 2758917

# %%
DF1.groupby('Year of Release')['vote'].mean().sort_values()
# Out:
# Year of Release
# 1962    6.276800e+04
# 2020    9.352150e+04
# 2017    1.084720e+05
# 1961    1.271880e+05
# 1985    1.309170e+05
# 2022    1.970682e+05
# 2016    2.000470e+05
# 2023    2.064680e+05
# 1959    3.373000e+05
# 1954    3.561130e+05
# 1997    4.124690e+05
# 2021    4.734595e+05
# 2018    4.758088e+05
# 2019    4.766972e+05
# 1995    6.867810e+05
# 1986    7.393740e+05
# 1989    7.874480e+05
# 1988    9.087280e+05
# 2012    9.322150e+05
# 1981    1.007793e+06
# 1993    1.027365e+06
# 1983    1.087899e+06
# 1991    1.135330e+06
# 1994    1.202153e+06
# 2003    1.220894e+06
# 1980    1.334656e+06
# 2005    1.336538e+06
# 1977    1.406687e+06
# 2000    1.552425e+06
# 2002    1.720128e+06
# 2001    1.934425e+06
# 1999    1.978806e+06
# 2010    2.449278e+06
# 2008    2.758917e+06
# Name: vote, dtype: float64

# %%
sns.barplot(x='vote',y='Year of Release',data=DF1)
# Out:
# <AxesSubplot:xlabel='vote', ylabel='Year of Release'>

# %% [markdown]
# # Second Prediction Gross

# %%
# Highest Average Gross(Revenue)
DF1.columns
# Out:
# Index(['Unnamed: 0', 'Name of movie', 'Director of movie', 'Duration of movie',
#        'Year of Release', 'Rating', 'Metascore', 'vote', 'gross', 'Genre',
#        'star', 'Certificate'],
#       dtype='object')

# %%
DF1['gross']
# Out:
# 0     $534.86M
# 1     $377.85M
# 2            _
# 3     $292.58M
# 4     $315.54M
# 5     $342.55M
# 6     $171.48M
# 7     $290.48M
# 8            _
# 9     $204.84M
# 10    $322.74M
# 11      $0.27M
# 12           _
# 13           _
# 14    $187.71M
# 15     $19.50M
# 16    $448.14M
# 17    $858.37M
# 18    $190.24M
# 19    $248.16M
# 20     $85.16M
# 21      $0.71M
# 22    $678.82M
# 23           _
# 24           _
# 25    $718.73M
# 26     $67.44M
# 27     $13.28M
# 28    $309.13M
# 29      $2.38M
# 30     $12.39M
# 31           _
# 32           _
# 33      $6.60M
# 34           _
# 35           _
# 36    $206.85M
# 37    $804.75M
# 38    $402.45M
# 39    $159.23M
# 40    $197.17M
# 41     $70.10M
# 42     $70.51M
# 43     $83.01M
# 44      $4.14M
# 45     $47.70M
# 46           _
# 47           _
# 48           _
# 49     $20.19M
# Name: gross, dtype: object

# %%
#Removing $ from gross
DF1['gross']=DF1['gross'].str.replace('$','')

# %%
#Removing M (millions)from gross
DF1['gross']=DF1['gross'].str.replace('M','')

# %%
DF1['gross']=DF1['gross'].str.replace('_','')

# %%
DF1['gross']=DF1['gross'].replace('',np.nan,regex=True)

# %%
DF1['gross']
# Out:
# 0     534.86
# 1     377.85
# 2        NaN
# 3     292.58
# 4     315.54
# 5     342.55
# 6     171.48
# 7     290.48
# 8        NaN
# 9     204.84
# 10    322.74
# 11      0.27
# 12       NaN
# 13       NaN
# 14    187.71
# 15     19.50
# 16    448.14
# 17    858.37
# 18    190.24
# 19    248.16
# 20     85.16
# 21      0.71
# 22    678.82
# 23       NaN
# 24       NaN
# 25    718.73
# 26     67.44
# 27     13.28
# 28    309.13
# 29      2.38
# 30     12.39
# 31       NaN
# 32       NaN
# 33      6.60
# 34       NaN
# 35       NaN
# 36    206.85
# 37    804.75
# 38    402.45
# 39    159.23
# 40    197.17
# 41     70.10
# 42     70.51
# 43     83.01
# 44      4.14
# 45     47.70
# 46       NaN
# 47       NaN
# 48       NaN
# 49     20.19
# Name: gross, dtype: object

# %%
#converting 'gross' object datatypes into int dtype 
DF1['gross']=pd.to_numeric(DF1['gross'])

# %%
DF1['gross']
# Out:
# 0     534.86
# 1     377.85
# 2        NaN
# 3     292.58
# 4     315.54
# 5     342.55
# 6     171.48
# 7     290.48
# 8        NaN
# 9     204.84
# 10    322.74
# 11      0.27
# 12       NaN
# 13       NaN
# 14    187.71
# 15     19.50
# 16    448.14
# 17    858.37
# 18    190.24
# 19    248.16
# 20     85.16
# 21      0.71
# 22    678.82
# 23       NaN
# 24       NaN
# 25    718.73
# 26     67.44
# 27     13.28
# 28    309.13
# 29      2.38
# 30     12.39
# 31       NaN
# 32       NaN
# 33      6.60
# 34       NaN
# 35       NaN
# 36    206.85
# 37    804.75
# 38    402.45
# 39    159.23
# 40    197.17
# 41     70.10
# 42     70.51
# 43     83.01
# 44      4.14
# 45     47.70
# 46       NaN
# 47       NaN
# 48       NaN
# 49     20.19
# Name: gross, dtype: float64

# %%
DF1['gross'].min(axis=0)
# Out:
# 0.27

# %%
DF1['gross'].max(axis=0)
# Out:
# 858.37

# %%
DF1.groupby('Year of Release')['gross'].mean().sort_values(ascending=False)
# Out:
# Year of Release
# 2021    804.750000
# 2008    534.860000
# 2019    508.800000
# 2012    448.140000
# 2018    434.530000
# 1993    402.450000
# 2022    362.665000
# 2002    342.550000
# 1977    322.740000
# 2001    315.540000
# 1983    309.130000
# 2010    292.580000
# 1980    290.480000
# 1981    248.160000
# 1991    204.840000
# 1989    197.170000
# 2000    187.710000
# 1999    171.480000
# 2003    149.553333
# 2005    138.680000
# 1986     85.160000
# 1988     83.010000
# 1995     67.440000
# 2020     47.700000
# 2017     20.190000
# 1994     19.500000
# 1959     13.280000
# 2016     12.390000
# 1985      4.140000
# 1997      2.380000
# 1954      0.270000
# 1961           NaN
# 1962           NaN
# 2023           NaN
# Name: gross, dtype: float64

# %%
sns.barplot(x='Year of Release',y='gross',data=DF1)

plt.show()

# %%
# Highest rating of movies and director
DF1.columns
# Out:
# Index(['Unnamed: 0', 'Name of movie', 'Director of movie', 'Duration of movie',
#        'Year of Release', 'Rating', 'Metascore', 'vote', 'gross', 'Genre',
#        'star', 'Certificate'],
#       dtype='object')

# %%
#Average rating for each director
DF1['Director of movie']
# Out:
# 0        Christopher Nolan
# 1            Peter Jackson
# 2     Joaquim Dos Santos,
# 3        Christopher Nolan
# 4            Peter Jackson
# 5            Peter Jackson
# 6         Lana Wachowski,
# 7           Irvin Kershner
# 8            Sudha Kongara
# 9            James Cameron
# 10            George Lucas
# 11          Akira Kurosawa
# 12        Masaki Kobayashi
# 13        Hanu Raghavapudi
# 14            Ridley Scott
# 15              Luc Besson
# 16       Christopher Nolan
# 17         Anthony Russo,
# 18       Bob Persichetti,
# 19        Steven Spielberg
# 20           James Cameron
# 21          Park Chan-wook
# 22         Anthony Russo,
# 23        Lokesh Kanagaraj
# 24             Vetrimaaran
# 25         Joseph Kosinski
# 26            Michael Mann
# 27        Alfred Hitchcock
# 28        Richard Marquand
# 29          Hayao Miyazaki
# 30           Nitesh Tiwari
# 31           Rishab Shetty
# 32        Lokesh Kanagaraj
# 33          Prashanth Neel
# ...

# %%
DF1['Rating']
# Out:
# 0       Rate this  123456789109/10X
# 1       Rate this  123456789109/10X
# 2     Rate this  123456789108.9/10X
# 3     Rate this  123456789108.8/10X
# 4     Rate this  123456789108.8/10X
# 5     Rate this  123456789108.8/10X
# 6     Rate this  123456789108.7/10X
# 7     Rate this  123456789108.7/10X
# 8     Rate this  123456789108.7/10X
# 9     Rate this  123456789108.6/10X
# 10    Rate this  123456789108.6/10X
# 11    Rate this  123456789108.6/10X
# 12    Rate this  123456789108.6/10X
# 13    Rate this  123456789108.6/10X
# 14    Rate this  123456789108.5/10X
# 15    Rate this  123456789108.5/10X
# 16    Rate this  123456789108.4/10X
# 17    Rate this  123456789108.4/10X
# 18    Rate this  123456789108.4/10X
# 19    Rate this  123456789108.4/10X
# 20    Rate this  123456789108.4/10X
# 21    Rate this  123456789108.4/10X
# 22    Rate this  123456789108.4/10X
# 23    Rate this  123456789108.4/10X
# 24    Rate this  123456789108.4/10X
# 25    Rate this  123456789108.3/10X
# ...

# %%
import re

# %%
# Remove the alphanumeric string
DF1['Rating']=DF1['Rating'].str.replace('\D','',regex=True)

# %%
DF1['Rating']=DF1['Rating'].str.replace('12345678910','',regex=True)

# %%
DF1['Rating']=DF1['Rating'].str.replace('10','',regex=True)

# %%
#changing the object Datatypes of 'Rating' into int dtypes
DF1['Rating']=DF1['Rating'].astype(float)

# %%
DF1['Rating']
# Out:
# 0      9.0
# 1      9.0
# 2     89.0
# 3     88.0
# 4     88.0
# 5     88.0
# 6     87.0
# 7     87.0
# 8     87.0
# 9     86.0
# 10    86.0
# 11    86.0
# 12    86.0
# 13    86.0
# 14    85.0
# 15    85.0
# 16    84.0
# 17    84.0
# 18    84.0
# 19    84.0
# 20    84.0
# 21    84.0
# 22    84.0
# 23    84.0
# 24    84.0
# 25    83.0
# 26    83.0
# 27    83.0
# 28    83.0
# 29    83.0
# 30    83.0
# 31    83.0
# 32    83.0
# 33    83.0
# 34    83.0
# 35    83.0
# 36    82.0
# 37    82.0
# 38    82.0
# 39    82.0
# 40    82.0
# 41    82.0
# 42    82.0
# 43    82.0
# 44    82.0
# 45    82.0
# 46    82.0
# 47    82.0
# 48    82.0
# 49    82.0
# Name: Rating, dtype: float64

# %%
DF1['Rating']=np.where(DF1['Rating']==9.0,90,DF1['Rating'])

# %%
DF1['Rating']
# Out:
# 0     90.0
# 1     90.0
# 2     89.0
# 3     88.0
# 4     88.0
# 5     88.0
# 6     87.0
# 7     87.0
# 8     87.0
# 9     86.0
# 10    86.0
# 11    86.0
# 12    86.0
# 13    86.0
# 14    85.0
# 15    85.0
# 16    84.0
# 17    84.0
# 18    84.0
# 19    84.0
# 20    84.0
# 21    84.0
# 22    84.0
# 23    84.0
# 24    84.0
# 25    83.0
# 26    83.0
# 27    83.0
# 28    83.0
# 29    83.0
# 30    83.0
# 31    83.0
# 32    83.0
# 33    83.0
# 34    83.0
# 35    83.0
# 36    82.0
# 37    82.0
# 38    82.0
# 39    82.0
# 40    82.0
# 41    82.0
# 42    82.0
# 43    82.0
# 44    82.0
# 45    82.0
# 46    82.0
# 47    82.0
# 48    82.0
# 49    82.0
# Name: Rating, dtype: float64

# %%
DF1['Rating']=DF1['Rating'].astype(int)

# %%
DF1['Rating']
# Out:
# 0     90
# 1     90
# 2     89
# 3     88
# 4     88
# 5     88
# 6     87
# 7     87
# 8     87
# 9     86
# 10    86
# 11    86
# 12    86
# 13    86
# 14    85
# 15    85
# 16    84
# 17    84
# 18    84
# 19    84
# 20    84
# 21    84
# 22    84
# 23    84
# 24    84
# 25    83
# 26    83
# 27    83
# 28    83
# 29    83
# 30    83
# 31    83
# 32    83
# 33    83
# 34    83
# 35    83
# 36    82
# 37    82
# 38    82
# 39    82
# 40    82
# 41    82
# 42    82
# 43    82
# 44    82
# 45    82
# 46    82
# 47    82
# 48    82
# 49    82
# Name: Rating, dtype: int32

# %%
DF1['Rating']=(DF1['Rating'].div(10))

# %%
DF1['Rating']
# Out:
# 0     9.0
# 1     9.0
# 2     8.9
# 3     8.8
# 4     8.8
# 5     8.8
# 6     8.7
# 7     8.7
# 8     8.7
# 9     8.6
# 10    8.6
# 11    8.6
# 12    8.6
# 13    8.6
# 14    8.5
# 15    8.5
# 16    8.4
# 17    8.4
# 18    8.4
# 19    8.4
# 20    8.4
# 21    8.4
# 22    8.4
# 23    8.4
# 24    8.4
# 25    8.3
# 26    8.3
# 27    8.3
# 28    8.3
# 29    8.3
# 30    8.3
# 31    8.3
# 32    8.3
# 33    8.3
# 34    8.3
# 35    8.3
# 36    8.2
# 37    8.2
# 38    8.2
# 39    8.2
# 40    8.2
# 41    8.2
# 42    8.2
# 43    8.2
# 44    8.2
# 45    8.2
# 46    8.2
# 47    8.2
# 48    8.2
# 49    8.2
# Name: Rating, dtype: float64

# %%
DF1.groupby('Director of movie')['Rating'].mean().sort_values()
# Out:
# Director of movie
# Anurag Kashyap          8.200000
# Sam Mendes              8.200000
# S.S. Rajamouli          8.200000
# Jon Watts               8.200000
# John McTiernan          8.200000
# Haruo Sotozaki          8.200000
# James McTeigue          8.200000
# Quentin Tarantino       8.200000
# Prashanth Neel          8.250000
# Steven Spielberg        8.266667
# Vishnuvardhan           8.300000
# Joseph Kosinski         8.300000
# Hayao Miyazaki          8.300000
# Nitesh Tiwari           8.300000
# Richard Marquand        8.300000
# Rishab Shetty           8.300000
# Alfred Hitchcock        8.300000
# Ram Kumar               8.300000
# Michael Mann            8.300000
# Akira Kurosawa          8.333333
# Lokesh Kanagaraj        8.350000
# Vetrimaaran             8.400000
# Anthony Russo,          8.400000
# Park Chan-wook          8.400000
# Bob Persichetti,        8.400000
# James Cameron           8.500000
# Luc Besson              8.500000
# Ridley Scott            8.500000
# ...

# %% [markdown]
# # Display top 10 lengthy Movies and  Duration of movie (runtime)

# %%
DF1.columns
# Out:
# Index(['Unnamed: 0', 'Name of movie', 'Director of movie', 'Duration of movie',
#        'Year of Release', 'Rating', 'Metascore', 'vote', 'gross', 'Genre',
#        'star', 'Certificate'],
#       dtype='object')

# %%
Top_10_Movies=DF1.nlargest(10,'Duration of movie')[['Name of movie','Duration of movie']]

# %%
DF1['Duration of movie']
# Out:
# 0     152
# 1     201
# 2     140
# 3     148
# 4     178
# 5     179
# 6     136
# 7     124
# 8     153
# 9     137
# 10    121
# 11    207
# 12    133
# 13    163
# 14    155
# 15    110
# 16    164
# 17    181
# 18    117
# 19    115
# 20    137
# 21    101
# 22    149
# 23    145
# 24    141
# 25    130
# 26    170
# 27    136
# 28    131
# 29    134
# 30    161
# 31    148
# 32    175
# 33    168
# 34    135
# 35    170
# 36    140
# 37    148
# 38    127
# 39    119
# 40    127
# 41    111
# 42    132
# 43    132
# 44    162
# 45    117
# 46    321
# 47    110
# 48    156
# 49    167
# Name: Duration of movie, dtype: int64

# %%
sns.barplot(x='Duration of movie',y=Top_10_Movies.index,data=Top_10_Movies)
# Out:
# <AxesSubplot:xlabel='Duration of movie'>

# %%
#Number of Movies per Year
DF1.columns
# Out:
# Index(['Unnamed: 0', 'Name of movie', 'Director of movie', 'Duration of movie',
#        'Year of Release', 'Rating', 'Metascore', 'vote', 'gross', 'Genre',
#        'star', 'Certificate'],
#       dtype='object')

# %%
# Number of movies release in particular year
DF1['Year of Release'].value_counts()
# Out:
# 2022    5
# 2019    4
# 2018    4
# 2003    3
# 2005    2
# 2020    2
# 2012    2
# 2021    2
# 1985    1
# 1988    1
# 1989    1
# 1993    1
# 1986    1
# 2016    1
# 1997    1
# 1983    1
# 1961    1
# 1959    1
# 1995    1
# 2008    1
# 1981    1
# 1994    1
# 2000    1
# 1962    1
# 1954    1
# 1977    1
# 1991    1
# 1980    1
# 1999    1
# 2002    1
# 2001    1
# 2010    1
# 2023    1
# 2017    1
# Name: Year of Release, dtype: int64

# %%
sns.countplot(x='Year of Release',data=DF1)
# Out:
# <AxesSubplot:xlabel='Year of Release', ylabel='count'>

# %% [markdown]
# # Most Popular Movie Name

# %%
DF1[DF1['gross'].max()==DF1['gross']]['Name of movie''']
# Out:
# 17    Avengers: Endgame
# Name: Name of movie, dtype: object

# %%
DF1['gross']
# Out:
# 0     534.86
# 1     377.85
# 2        NaN
# 3     292.58
# 4     315.54
# 5     342.55
# 6     171.48
# 7     290.48
# 8        NaN
# 9     204.84
# 10    322.74
# 11      0.27
# 12       NaN
# 13       NaN
# 14    187.71
# 15     19.50
# 16    448.14
# 17    858.37
# 18    190.24
# 19    248.16
# 20     85.16
# 21      0.71
# 22    678.82
# 23       NaN
# 24       NaN
# 25    718.73
# 26     67.44
# 27     13.28
# 28    309.13
# 29      2.38
# 30     12.39
# 31       NaN
# 32       NaN
# 33      6.60
# 34       NaN
# 35       NaN
# 36    206.85
# 37    804.75
# 38    402.45
# 39    159.23
# 40    197.17
# 41     70.10
# 42     70.51
# 43     83.01
# 44      4.14
# 45     47.70
# 46       NaN
# 47       NaN
# 48       NaN
# 49     20.19
# Name: gross, dtype: float64

# %%
DF1.columns
# Out:
# Index(['Unnamed: 0', 'Name of movie', 'Director of movie', 'Duration of movie',
#        'Year of Release', 'Rating', 'Metascore', 'vote', 'gross', 'Genre',
#        'star', 'Certificate'],
#       dtype='object')

# %% [markdown]
# # Top 10 largest movie name,with their director name and rating

# %%
Top_10_Movies=DF1.nlargest(10,'Rating')[['Name of movie','Rating','Director of movie']]\
.set_index('Name of movie')

# %%
Top_10_Movies
# Out:
#                                                    Rating  \
# Name of movie
# The Dark Knight                                       9.0
# The Lord of the Rings: The Return of the King         9.0
# Spider-Man: Across the Spider-Verse                   8.9
# Inception                                             8.8
# The Lord of the Rings: The Fellowship of the Ring     8.8
# The Lord of the Rings: The Two Towers                 8.8
# The Matrix                                            8.7
# Star Wars: Episode V - The Empire Strikes Back        8.7
# Soorarai Pottru                                       8.7
# Terminator 2: Judgment Day                            8.6
#
#                                                       Director of movie
# Name of movie
# The Dark Knight                                       Christopher Nolan
# The Lord of the Rings: The Return of the King             Peter Jackson
# Spider-Man: Across the Spider-Verse                Joaquim Dos Santos,
# ...

# %%
sns.barplot(x='Rating',y=Top_10_Movies.index,data=Top_10_Movies,hue='Director of movie',dodge=False)
plt.legend(bbox_to_anchor=(1.05,1),loc=2)

# %% [markdown]
# # Top 10 higest gross(Revenue)  movie name

# %%
top_10=DF1.nlargest(10,'gross')[['Name of movie','gross']]\
.set_index('Name of movie')

# %%
top_10
# Out:
#                                                 gross
# Name of movie
# Avengers: Endgame                              858.37
# Spider-Man: No Way Home                        804.75
# Top Gun: Maverick                              718.73
# Avengers: Infinity War                         678.82
# The Dark Knight                                534.86
# The Dark Knight Rises                          448.14
# Jurassic Park                                  402.45
# The Lord of the Rings: The Return of the King  377.85
# The Lord of the Rings: The Two Towers          342.55
# Star Wars                                      322.74

# %%
sns.barplot(x='gross',y=top_10.index,data=top_10)
plt.title("Top 10 highest gross Movie name")
plt.show()

# %%
# Average Rating  Movies year wise

# %%
DF1.columns
# Out:
# Index(['Unnamed: 0', 'Name of movie', 'Director of movie', 'Duration of movie',
#        'Year of Release', 'Rating', 'Metascore', 'vote', 'gross', 'Genre',
#        'star', 'Certificate'],
#       dtype='object')

# %%
DF1.groupby('Year of Release')['Rating'].mean().sort_values()
# Out:
# Year of Release
# 1989    8.200000
# 2017    8.200000
# 1993    8.200000
# 1988    8.200000
# 1985    8.200000
# 2005    8.200000
# 1961    8.200000
# 2021    8.250000
# 1997    8.300000
# 1983    8.300000
# 2012    8.300000
# 2016    8.300000
# 1959    8.300000
# 1995    8.300000
# 2018    8.325000
# 2019    8.350000
# 2022    8.360000
# 1981    8.400000
# 1986    8.400000
# 2020    8.450000
# 2000    8.500000
# 1994    8.500000
# 2003    8.533333
# 1954    8.600000
# 1991    8.600000
# 1977    8.600000
# 1962    8.600000
# 1999    8.700000
# 1980    8.700000
# 2010    8.800000
# 2002    8.800000
# 2001    8.800000
# 2023    8.900000
# 2008    9.000000
# Name: Rating, dtype: float64

# %% [markdown]
# # Does Rating affect the gross

# %%
sns.scatterplot(x='Rating',y='gross',data=DF1)
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='gross'>

# %% [markdown]
# # Classifying Movies based on Ratings [Excellent,Good and Average]

# %%
DF1.columns
# Out:
# Index(['Unnamed: 0', 'Name of movie', 'Director of movie', 'Duration of movie',
#        'Year of Release', 'Rating', 'Metascore', 'vote', 'gross', 'Genre',
#        'star', 'Certificate'],
#       dtype='object')

# %%
DF1['Rating']
# Out:
# 0     9.0
# 1     9.0
# 2     8.9
# 3     8.8
# 4     8.8
# 5     8.8
# 6     8.7
# 7     8.7
# 8     8.7
# 9     8.6
# 10    8.6
# 11    8.6
# 12    8.6
# 13    8.6
# 14    8.5
# 15    8.5
# 16    8.4
# 17    8.4
# 18    8.4
# 19    8.4
# 20    8.4
# 21    8.4
# 22    8.4
# 23    8.4
# 24    8.4
# 25    8.3
# 26    8.3
# 27    8.3
# 28    8.3
# 29    8.3
# 30    8.3
# 31    8.3
# 32    8.3
# 33    8.3
# 34    8.3
# 35    8.3
# 36    8.2
# 37    8.2
# 38    8.2
# 39    8.2
# 40    8.2
# 41    8.2
# 42    8.2
# 43    8.2
# 44    8.2
# 45    8.2
# 46    8.2
# 47    8.2
# 48    8.2
# 49    8.2
# Name: Rating, dtype: float64

# %%
def rating(rating):
    if rating>=9.0:
        return "Excellent"
    elif rating>=8.4:
        return "Good"
    else:
        return "Average"

# %%
DF1['Rating_new']=DF1['Rating'].apply(rating)

# %%
DF1.head()
# Out:
#    Unnamed: 0                                      Name of movie  \
# 0           0                                    The Dark Knight
# 1           1      The Lord of the Rings: The Return of the King
# 2           2                Spider-Man: Across the Spider-Verse
# 3           3                                          Inception
# 4           4  The Lord of the Rings: The Fellowship of the Ring
#
#       Director of movie  Duration of movie  Year of Release  Rating  \
# 0     Christopher Nolan                152             2008     9.0
# 1         Peter Jackson                201             2003     9.0
# 2  Joaquim Dos Santos,                 140             2023     8.9
# 3     Christopher Nolan                148             2010     8.8
# 4         Peter Jackson                178             2001     8.8
#
#     Metascore     vote   gross                                      Genre  \
# 0  84          2758917  534.86           Action, Crime, Drama
# ...

# %% [markdown]
# # Count Number of Action Movies

# %%
DF1.columns
# Out:
# Index(['Unnamed: 0', 'Name of movie', 'Director of movie', 'Duration of movie',
#        'Year of Release', 'Rating', 'Metascore', 'vote', 'gross', 'Genre',
#        'star', 'Certificate', 'Rating_new'],
#       dtype='object')

# %%
DF1['Genre'].dtype
# Out:
# dtype('O')

# %%
DF1['Genre'].str.contains('Action',case=False)
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# 29    True
# 30    True
# 31    True
# 32    True
# 33    True
# 34    True
# 35    True
# 36    True
# 37    True
# 38    True
# 39    True
# 40    True
# 41    True
# 42    True
# 43    True
# 44    True
# 45    True
# 46    True
# 47    True
# 48    True
# 49    True
# Name: Genre, dtype: bool

# %%
DF1['Genre']
# Out:
# 0              Action, Crime, Drama
# 1          Action, Adventure, Drama
# 2      Animation, Action, Adventure
# 3         Action, Adventure, Sci-Fi
# 4          Action, Adventure, Drama
# 5          Action, Adventure, Drama
# 6                    Action, Sci-Fi
# 7        Action, Adventure, Fantasy
# 8                     Action, Drama
# 9                    Action, Sci-Fi
# 10       Action, Adventure, Fantasy
# 11                    Action, Drama
# 12           Action, Drama, Mystery
# 13           Action, Drama, Mystery
# 14         Action, Adventure, Drama
# 15             Action, Crime, Drama
# 16          Action, Drama, Thriller
# 17         Action, Adventure, Drama
# 18     Animation, Action, Adventure
# 19                Action, Adventure
# 20        Action, Adventure, Sci-Fi
# 21           Action, Drama, Mystery
# 22        Action, Adventure, Sci-Fi
# 23         Action, Adventure, Crime
# 24                    Action, Drama
# 25                    Action, Drama
# ...

# %%
DF1['Genre'].unique()
# Out:
# array([' Action, Crime, Drama            ',
#        ' Action, Adventure, Drama            ',
#        ' Animation, Action, Adventure            ',
#        ' Action, Adventure, Sci-Fi            ',
#        ' Action, Sci-Fi            ',
#        ' Action, Adventure, Fantasy            ',
#        ' Action, Drama            ',
#        ' Action, Drama, Mystery            ',
#        ' Action, Drama, Thriller            ',
#        ' Action, Adventure            ',
#        ' Action, Adventure, Crime            ',
#        ' Action, Adventure, Mystery            ',
#        ' Action, Biography, Drama            ',
#        ' Action, Crime, Thriller            ',
#        ' Action, Drama, War            ',
#        ' Action, Drama, Sci-Fi            ',
#        ' Action, Thriller            ',
#        ' Action, Comedy, Crime            '], dtype=object)

# %%
DF1['Metascore']
# Out:
# 0     84
# 1     94
# 2     86
# 3     74
# 4     92
# 5     87
# 6     73
# 7     82
# 8           ^^^^
# 9     75
# 10    90
# 11    98
# 12    85
# 13          ^^^^
# 14    67
# 15    64
# 16    78
# 17    78
# 18    87
# 19    85
# 20    84
# 21    77
# 22    68
# 23          ^^^^
# 24          ^^^^
# 25    78
# 26    76
# 27    98
# 28    58
# 29    76
# 30          ^^^^
# 31          ^^^^
# 32          ^^^^
# 33          ^^^^
# 34          ^^^^
# 35          ^^^^
# 36    70
# 37    71
# 38    68
# 39    78
# 40    65
# 41    69
# 42    62
# 43    72
# 44    97
# 45    72
# 46    89
# 47    93
# 48          ^^^^
# 49          ^^^^
# Name: Metascore, dtype: object

# %%
list1=[]
for value in DF1['Genre']:
   list1.append(value.split(','))

# %%
list1
# Out:
# [[' Action', ' Crime', ' Drama            '],
#  [' Action', ' Adventure', ' Drama            '],
#  [' Animation', ' Action', ' Adventure            '],
#  [' Action', ' Adventure', ' Sci-Fi            '],
#  [' Action', ' Adventure', ' Drama            '],
#  [' Action', ' Adventure', ' Drama            '],
#  [' Action', ' Sci-Fi            '],
#  [' Action', ' Adventure', ' Fantasy            '],
#  [' Action', ' Drama            '],
#  [' Action', ' Sci-Fi            '],
#  [' Action', ' Adventure', ' Fantasy            '],
#  [' Action', ' Drama            '],
#  [' Action', ' Drama', ' Mystery            '],
#  [' Action', ' Drama', ' Mystery            '],
#  [' Action', ' Adventure', ' Drama            '],
#  [' Action', ' Crime', ' Drama            '],
#  [' Action', ' Drama', ' Thriller            '],
#  [' Action', ' Adventure', ' Drama            '],
#  [' Animation', ' Action', ' Adventure            '],
#  [' Action', ' Adventure            '],
# ...

# %%
one_d=[]
for item in list1:
    for item1 in item:
        one_d.append(item1)

# %%
one_d
# Out:
# [' Action',
#  ' Crime',
#  ' Drama            ',
#  ' Action',
#  ' Adventure',
#  ' Drama            ',
#  ' Animation',
#  ' Action',
#  ' Adventure            ',
#  ' Action',
#  ' Adventure',
#  ' Sci-Fi            ',
#  ' Action',
#  ' Adventure',
#  ' Drama            ',
#  ' Action',
#  ' Adventure',
#  ' Drama            ',
#  ' Action',
#  ' Sci-Fi            ',
#  ' Action',
#  ' Adventure',
#  ' Fantasy            ',
#  ' Action',
#  ' Drama            ',
#  ' Action',
#  ' Sci-Fi            ',
#  ' Action',
#  ' Adventure',
#  ' Fantasy            ',
#  ' Action',
#  ' Drama            ',
#  ' Action',
#  ' Drama',
#  ' Mystery            ',
#  ' Action',
#  ' Drama',
#  ' Mystery            ',
#  ' Action',
#  ' Adventure',
#  ' Drama            ',
#  ' Action',
#  ' Crime',
#  ' Drama            ',
#  ' Action',
#  ' Drama',
#  ' Thriller            ',
#  ' Action',
#  ' Adventure',
#  ' Drama            ',
#  ' Animation',
#  ' Action',
#  ' Adventure            ',
# ...

# %%
uni_list=[]
for item in one_d:
    if item not in uni_list:
        uni_list.append(item)

# %% [markdown]
# # HOW MANY MOVIES OF EACH GENRE WERE MADE

# %%
len(uni_list)
# Out:
# 15

# %%
from collections import Counter

# %%
Counter(one_d)
# Out:
# Counter({' Action': 50,
#          ' Crime': 9,
#          ' Drama            ': 20,
#          ' Adventure': 16,
#          ' Animation': 4,
#          ' Adventure            ': 6,
#          ' Sci-Fi            ': 7,
#          ' Fantasy            ': 4,
#          ' Drama': 8,
#          ' Mystery            ': 4,
#          ' Thriller            ': 5,
#          ' Crime            ': 2,
#          ' Biography': 2,
#          ' War            ': 2,
#          ' Comedy': 1})
